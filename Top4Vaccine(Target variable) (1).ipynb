# %% [markdown]
# # Load the Data

# %%
# import the necessary libraries
import pandas as pd
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv(r'C:\Users\spoor\Downloads\cleaned_vaers.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328255 entries, 0 to 328254
# Data columns (total 35 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         328255 non-null  int64
#  1   STATE            328255 non-null  object
#  2   AGE_YRS          328255 non-null  float64
#  3   SEX              328255 non-null  int64
#  4   SYMPTOM_TEXT     328255 non-null  object
#  5   DIED             328255 non-null  int64
#  6   L_THREAT         328255 non-null  int64
#  7   HOSPITAL         328255 non-null  int64
#  8   HOSPDAYS         328255 non-null  float64
#  9   DISABLE          328255 non-null  int64
#  10  RECOVD           328255 non-null  int64
#  11  VAX_DATE         328255 non-null  object
#  12  ONSET_DATE       328255 non-null  object
#  13  NUMDAYS          328255 non-null  int64
#  14  V_ADMINBY        328255 non-null  object
#  15  OTHER_MEDS       213171 non-null  object
#  16  CUR_ILL          141840 non-null  object
#  17  HISTORY          195636 non-null  object
#  18  BIRTH_DEFECT     328255 non-null  int64
#  19  ALLERGIES        201071 non-null  object
#  20  ORDER_x          328255 non-null  int64
#  21  VAX_TYPE         328255 non-null  object
#  22  VAX_MANU         328255 non-null  object
#  23  VAX_LOT          236035 non-null  object
#  24  VAX_DOSE_SERIES  319085 non-null  object
#  25  VAX_ROUTE        288714 non-null  object
#  26  VAX_SITE         289637 non-null  object
#  27  VAX_NAME         328255 non-null  object
#  28  ORDER_y          328255 non-null  int64
#  29  SYMPTOM1         328255 non-null  object
#  30  SYMPTOM2         328255 non-null  object
#  31  SYMPTOM3         328255 non-null  object
#  32  SYMPTOM4         328255 non-null  object
#  33  SYMPTOM5         328255 non-null  object
#  34  ORDER            328255 non-null  int64
# dtypes: float64(2), int64(12), object(21)
# memory usage: 87.7+ MB

# %% [markdown]
# ## Defining target variable - SERIOUS

# %%
# Define the function to check serious criteria
def serious_criteria(row):

    if any(row[col] == 1 for col in ['DIED', 'L_THREAT', 'HOSPITAL', 'DISABLE', 'BIRTH_DEFECT']):
        return 1
    else:
        return 0

# %% [markdown]
# ## Check with the medDRA important medical event terms list

# %%
# List of fields/columns interested
fields = ['MedDRA Code', 'PT Name', 'SOC Name']

file_path = r"C:\Users\spoor\Downloads\MedDRA_27.1.xlsx"
# Read the Excel file starting from row 12
medDRA = pd.read_excel(file_path, usecols=fields, skiprows=11)
medDRA
# Out:
#       MedDRA Code                            PT Name  \
# 0        10091289  Arrhythmia induced cardiomyopathy
# 1        10090743                       Ewart's sign
# 2        10090970         Hypothyroid cardiomyopathy
# 3        10090793            Pericardial perforation
# 4        10091259                           Agnathia
# ...           ...                                ...
# 7615     10047193                 Vena cava embolism
# 7616     10047195               Vena cava thrombosis
# 7617     10067030     Venous thrombosis in pregnancy
# 7618     10064602         Venous thrombosis neonatal
# 7619     10066397                Visceral congestion
#
#                                         SOC Name
# 0                              Cardiac disorders
# 1                              Cardiac disorders
# 2                              Cardiac disorders
# 3                              Cardiac disorders
# 4     Congenital, familial and genetic disorders
# ...                                          ...
# 7615                          Vascular disorders
# 7616                          Vascular disorders
# 7617                          Vascular disorders
# 7618                          Vascular disorders
# 7619                          Vascular disorders
#
# [7620 rows x 3 columns]

# %%
list_of_names = medDRA['PT Name'].to_list()
list_of_names = [i.lower() for i in list_of_names]
print('List of Names: ', list_of_names)
print('Type of listOfNames: ', type(list_of_names))
# Out:
# List of Names:  ['arrhythmia induced cardiomyopathy', "ewart's sign", 'hypothyroid cardiomyopathy', 'pericardial perforation', 'agnathia', 'body stalk anomaly', 'disseminated neonatal herpes simplex', 'embryo-foetal toxicity', 'uterine cervix agenesis', 'lupus retinopathy', 'proliferative vitreoretinopathy', 'atypical stevens-johnson syndrome', 'enterocolic phlebitis', 'immune-mediated proctitis', 'left-sided portal hypertension', 'immune-mediated mucositis', 'hepatic vascular fistula', 'metabolic dysfunction-associated steatohepatitis', 'immune-mediated adverse reaction', 'actinomyces bacteraemia', 'central nervous system bacterial infection', 'disseminated escherichia infection', 'gemella infection', 'gut derived infection', 'prevertebral space infection', 'sepsis associated acute kidney injury', 'traumatic subarachnoid haemorrhage', 'neonatal metabolic bone disease', "ewing's sarcoma of adrenal gland", 'gastrointestinal autonomic nerve tumour', 'gastrointestinal neuroendocrine tumour', 'iatrogenic kaposi sarcoma', 'melanocytic tumour of uncertain malignant potential', 'myelodysplastic syndrome/myeloproliferative neoplasm overlap syndrome', 'myoepithelial carcinoma of salivary gland', 'neuroendocrine tumour of the thymus', 'non-clear cell renal cell carcinoma', 'vasoproliferative retinal tumour', 'atypical parkinsonism', 'bobble-head doll syndrome', 'dorsal root ganglionopathy', 'myocarditis-myositis-myasthenia gravis overlap syndrome', 'spontaneous subdural haematoma', 'thalamic microhaemorrhage', 'succenturiate placenta', 'post pulmonary embolism syndrome', 'pulmonary inflammatory pseudotumour', "gottron's papules", 'immune-mediated dermatitis', 'autoimmune vasculitis', 'superior mediastinal syndrome', 'dermatomyositis', 'paraneoplastic dermatomyositis', 'cavernous sinus thrombosis', 'acquired amegakaryocytic thrombocytopenia', 'acquired factor ix deficiency', 'acquired factor v deficiency', 'acquired factor viii deficiency', 'acquired factor xi deficiency', 'acquired haemoglobinopathy', 'acquired haemophilia', 'acquired thalassaemia', "acquired von willebrand's disease", 'agranulocytosis', 'allergic lymphangitis', 'antiphospholipid syndrome', 'aplasia pure red cell', 'aplastic anaemia', 'atypical haemolytic uraemic syndrome', 'autoimmune anaemia', 'autoimmune aplastic anaemia', 'autoimmune haemolytic anaemia', 'autoimmune heparin-induced thrombocytopenia', 'autoimmune neutropenia', 'autoimmune pancytopenia', 'b-cell aplasia', 'bicytopenia', 'blood loss anaemia', 'bone marrow failure', 'bone marrow infiltration', 'bone marrow necrosis', 'breakthrough haemolysis', 'carboxyhaemoglobinaemia', 'cardiac haemolytic anaemia', 'clonal cytopenia of undetermined significance', 'coagulation disorder neonatal', 'cold type haemolytic anaemia', 'coombs negative haemolytic anaemia', 'coombs positive haemolytic anaemia', 'cutaneous extramedullary haemopoiesis', 'cytopenia', 'diffuse infiltrative lymphocytosis syndrome', 'disseminated intravascular coagulation', 'disseminated intravascular coagulation in newborn', 'elephantiasis', 'eosinophilia myalgia syndrome', 'erythroid dysplasia', 'erythroid maturation arrest', 'erythropoiesis abnormal', 'erythropoietin deficiency anaemia', 'evans syndrome', 'extravascular haemolysis', 'factor ix inhibition', 'factor viii inhibition', 'febrile bone marrow aplasia', 'febrile neutropenia', 'foetal anaemia', 'gelatinous transformation of the bone marrow', 'granulocytes maturation arrest', 'granulocytopenia', 'granulocytopenia neonatal', 'granulomatous lymphadenitis', 'haemoglobinaemia', 'haemolysis', 'haemolysis neonatal', 'haemolytic anaemia', 'haemolytic icteroanaemia', 'haemolytic uraemic syndrome', 'haemorrhagic disease of newborn', 'heparin-induced thrombocytopenia', 'hypereosinophilic syndrome', 'hyperfibrinolysis', 'hyperleukocytosis', 'hyperviscosity syndrome', 'hypoplastic anaemia', 'hyposplenism', 'idiopathic cd4 lymphocytopenia', 'idiopathic cytopenia of undetermined significance', 'immune eff ...
# Type of listOfNames:  <class 'list'>

# %% [markdown]
# # PPV

# %%
ppv_df = df[df['VAX_TYPE'].str.contains('PPV')]
ppv_df = ppv_df.drop('VAX_TYPE', axis=1)

# %%
# Apply the function to create the 'serious' column
ppv_df['SERIOUS'] = ppv_df.apply(serious_criteria, axis=1)

# %%
ppv_df['SERIOUS'].value_counts()
# Out:
# SERIOUS
# 0    16339
# Name: count, dtype: int64

# %%
# %%time 
# Create a function that returns 1 if any symptom matches with MedDRA terms, 0 otherwise
def has_meddra_match(row):
    for col in ['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']:
        if pd.notna(row[col]) and row[col].lower() in list_of_names:
            return 1
    return 0

# Create new column 'HAS_MEDDRA_MATCH'
ppv_df['HAS_MEDDRA_MATCH'] = ppv_df.apply(has_meddra_match, axis=1)

# You can verify the results
print(f"Number of records with MedDRA matches: {ppv_df['HAS_MEDDRA_MATCH'].sum()}")
print(f"Number of records without MedDRA matches: {(ppv_df['HAS_MEDDRA_MATCH'] == 0).sum()}")
# Out:
# Number of records with MedDRA matches: 731
# Number of records without MedDRA matches: 15608
# CPU times: total: 15.8 s
# Wall time: 16.5 s

# %%
ppv_df['SERIOUS'] = ppv_df['SERIOUS'] + ppv_df['HAS_MEDDRA_MATCH']
ppv_df['SERIOUS'] = ppv_df['SERIOUS'].apply(lambda x: 0 if x == 0 else 1)
#ppv_df = ppv_df.drop(columns=['HAS_MEDDRA_MATCH'])

# %%
ppv_df.head(2)
# Out:
#     VAERS_ID STATE  AGE_YRS  SEX  \
# 41    573481    WI     42.0    1
# 42    573481    WI     42.0    1
#
#                                          SYMPTOM_TEXT  DIED  L_THREAT  \
# 41  THIS SPONTANEOUS REPORT WAS RECEIVED FROM A PH...     0         0
# 42  THIS SPONTANEOUS REPORT WAS RECEIVED FROM A PH...     0         0
#
#     HOSPITAL  HOSPDAYS  DISABLE  ...            VAX_NAME ORDER_y  \
# 41         0       0.0        0  ...  PNEUMO (PNEUMOVAX)       1
# 42         0       0.0        0  ...  PNEUMO (PNEUMOVAX)       1
#
#                   SYMPTOM1                       SYMPTOM2  \
# 41                 AUTOPSY                          DEATH
# 42  VARICELLA POST VACCINE  VARICELLA VIRUS TEST POSITIVE
#
#                SYMPTOM3                   SYMPTOM4 SYMPTOM5 ORDER  SERIOUS  \
# 41  MULTI-ORGAN FAILURE  POLYMERASE CHAIN REACTION   SEPSIS     1        1
# 42                                                              1        0
#
#    HAS_MEDDRA_MATCH
# 41                1
# 42                0
#
# [2 rows x 36 columns]

# %%
ppv_df.to_csv(r'C:\Users\spoor\Downloads\ppv.csv', index=False)

# %% [markdown]
# # VARZOS

# %%
varzos_df = df[df['VAX_TYPE'].str.contains('VARZOS')]
varzos_df = varzos_df.drop('VAX_TYPE', axis=1)

# %%
# Apply the function to create the 'serious' column
varzos_df['SERIOUS'] = varzos_df.apply(serious_criteria, axis=1)
varzos_df['SERIOUS'].value_counts()
# Out:
# SERIOUS
# 0    53120
# Name: count, dtype: int64

# %%
# %%time 
# Create a function that returns 1 if any symptom matches with MedDRA terms, 0 otherwise
def has_meddra_match(row):
    for col in ['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']:
        if pd.notna(row[col]) and row[col].lower() in list_of_names:
            return 1
    return 0
    
# Create new column 'HAS_MEDDRA_MATCH'
varzos_df['HAS_MEDDRA_MATCH'] = varzos_df.apply(has_meddra_match, axis=1)

# You can verify the results
print(f"Number of records with MedDRA matches: {varzos_df['HAS_MEDDRA_MATCH'].sum()}")
print(f"Number of records without MedDRA matches: {(varzos_df['HAS_MEDDRA_MATCH'] == 0).sum()}")
# Out:
# Number of records with MedDRA matches: 3257
# Number of records without MedDRA matches: 49863
# CPU times: total: 54.5 s
# Wall time: 56.7 s

# %%
varzos_df['SERIOUS'] = varzos_df['SERIOUS'] + varzos_df['HAS_MEDDRA_MATCH']
varzos_df['SERIOUS'] = varzos_df['SERIOUS'].apply(lambda x: 0 if x == 0 else 1)
varzos_df = varzos_df.drop(columns=['HAS_MEDDRA_MATCH'])

# %%
varzos_df.head(2)
# Out:
#     VAERS_ID STATE  AGE_YRS  SEX         SYMPTOM_TEXT  DIED  L_THREAT  \
# 39    571772    MA     75.0    0  REDNESS AND ITCHING     0         0
# 40    571772    MA     75.0    0  REDNESS AND ITCHING     0         0
#
#     HOSPITAL  HOSPDAYS  DISABLE  ...  VAX_SITE                VAX_NAME  \
# 39         0       0.0        0  ...        LA  ZOSTER LIVE (ZOSTAVAX)
# 40         0       0.0        0  ...        LA  ZOSTER LIVE (ZOSTAVAX)
#
#    ORDER_y                 SYMPTOM1                 SYMPTOM2     SYMPTOM3  \
# 39       1  INJECTION SITE ERYTHEMA  INJECTION SITE SWELLING  RHINORRHOEA
# 40       1                 ERYTHEMA                 PRURITUS
#
#              SYMPTOM4 SYMPTOM5  ORDER SERIOUS
# 39  THROAT IRRITATION               1       0
# 40                                  2       0
#
# [2 rows x 35 columns]

# %%
varzos_df.to_csv(r'C:\Users\spoor\Downloads\varzos.csv', index=False)

# %% [markdown]
# # FLU

# %%
flu_df = df[df['VAX_TYPE'].str.contains('FLU')]
flu_df = flu_df.drop('VAX_TYPE', axis=1)

# %%
# Apply the function to create the 'serious' column
flu_df['SERIOUS'] = flu_df.apply(serious_criteria, axis=1)
flu_df['SERIOUS'].value_counts()
# Out:
# SERIOUS
# 0    49562
# Name: count, dtype: int64

# %%
# %%time
# Create a function that returns 1 if any symptom matches with MedDRA terms, 0 otherwise
def has_meddra_match(row):
    for col in ['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']:
        if pd.notna(row[col]) and row[col].lower() in list_of_names:
            return 1
    return 0

# Create new column 'HAS_MEDDRA_MATCH'
flu_df['HAS_MEDDRA_MATCH'] = flu_df.apply(has_meddra_match, axis=1)

# You can verify the results
print(f"Number of records with MedDRA matches: {flu_df['HAS_MEDDRA_MATCH'].sum()}")
print(f"Number of records without MedDRA matches: {(flu_df['HAS_MEDDRA_MATCH'] == 0).sum()}")
# Out:
# Number of records with MedDRA matches: 5558
# Number of records without MedDRA matches: 44004
# CPU times: total: 48.7 s
# Wall time: 50.9 s

# %%
flu_df['SERIOUS'] = flu_df['SERIOUS'] + flu_df['HAS_MEDDRA_MATCH']
flu_df['SERIOUS'] = flu_df['SERIOUS'].apply(lambda x: 0 if x == 0 else 1)
flu_df = flu_df.drop(columns=['HAS_MEDDRA_MATCH'])

# %%
flu_df.head(2)
# Out:
#      VAERS_ID STATE  AGE_YRS  SEX  \
# 133    622060    WA     39.0    0
# 134    622060    WA     39.0    0
#
#                                           SYMPTOM_TEXT  DIED  L_THREAT  \
# 133  AFTER THE VACCINE MY SHOULDER HURT BUT I THOUG...     0         0
# 134  AFTER THE VACCINE MY SHOULDER HURT BUT I THOUG...     0         0
#
#      HOSPITAL  HOSPDAYS  DISABLE  ...  VAX_SITE  \
# 133         0       0.0        0  ...        AR
# 134         0       0.0        0  ...        AR
#
#                             VAX_NAME ORDER_y               SYMPTOM1 SYMPTOM2  \
# 133  INFLUENZA (SEASONAL) (FLUVIRIN)       1  VACCINATION SITE PAIN
# 134  INFLUENZA (SEASONAL) (FLUVIRIN)       1    INJECTION SITE PAIN
#
#     SYMPTOM3 SYMPTOM4 SYMPTOM5  ORDER SERIOUS
# 133                                 1       0
# 134                                 2       0
#
# [2 rows x 35 columns]

# %%
flu_df.to_csv(r'C:\Users\spoor\Downloads\flu.csv', index=False)

# %% [markdown]
# # COVID

# %%
covid_df = df[df['VAX_TYPE'].str.contains('COVID')]
covid_df = covid_df.drop('VAX_TYPE', axis=1)

# %%
# Apply the function to create the 'serious' column
covid_df['SERIOUS'] = covid_df.apply(serious_criteria, axis=1)
covid_df['SERIOUS'].value_counts()
# Out:
# SERIOUS
# 0    118274
# Name: count, dtype: int64

# %%
# %%time 
# Create a function that returns 1 if any symptom matches with MedDRA terms, 0 otherwise
def has_meddra_match(row):
    for col in ['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']:
        if pd.notna(row[col]) and row[col].lower() in list_of_names:
            return 1
    return 0

# Create new column 'HAS_MEDDRA_MATCH'
covid_df['HAS_MEDDRA_MATCH'] = covid_df.apply(has_meddra_match, axis=1)

# You can verify the results
print(f"Number of records with MedDRA matches: {covid_df['HAS_MEDDRA_MATCH'].sum()}")
print(f"Number of records without MedDRA matches: {(covid_df['HAS_MEDDRA_MATCH'] == 0).sum()}")
# Out:
# Number of records with MedDRA matches: 9987
# Number of records without MedDRA matches: 108287
# CPU times: total: 2min 2s
# Wall time: 2min 6s

# %%
covid_df['SERIOUS'] = covid_df['SERIOUS'] + covid_df['HAS_MEDDRA_MATCH']
covid_df['SERIOUS'] = covid_df['SERIOUS'].apply(lambda x: 0 if x == 0 else 1)
covid_df = covid_df.drop(columns=['HAS_MEDDRA_MATCH'])

# %%
covid_df.head(2)
# Out:
#         VAERS_ID STATE  AGE_YRS  SEX  \
# 203470    902418    NJ     56.0    0
# 203476    902440    AZ     35.0    0
#
#                                              SYMPTOM_TEXT  DIED  L_THREAT  \
# 203470  PATIENT EXPERIENCED MILD NUMBNESS TRAVELING FR...     0         0
# 203476                                       C O HEADACHE     0         0
#
#         HOSPITAL  HOSPDAYS  DISABLE  ...  VAX_SITE  \
# 203470         0       0.0        0  ...        LA
# 203476         0       0.0        0  ...        LA
#
#                                    VAX_NAME ORDER_y       SYMPTOM1  \
# 203470  COVID19 (COVID19 (PFIZER-BIONTECH))       1  HYPOAESTHESIA
# 203476  COVID19 (COVID19 (PFIZER-BIONTECH))       1       HEADACHE
#
#                             SYMPTOM2 SYMPTOM3 SYMPTOM4 SYMPTOM5  ORDER SERIOUS
# 203470  INJECTION SITE HYPOAESTHESIA                                 1       0
# 203476                                                               1       0
#
# [2 rows x 35 columns]

# %%
covid_df.to_csv(r'C:\Users\spoor\Downloads\covid.csv', index=False)
